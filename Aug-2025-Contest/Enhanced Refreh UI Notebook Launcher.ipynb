# %%
# ───────────────────────────────────────────────
# For Aug 2025 Fabric Notebook Contest
# Author  : Jai Rathinavel  
# LinkedIn: https://www.linkedin.com/in/jai-rathinavel  
# Github  : https://github.com/jai-rathinavel
# Year    : 2025  
# Month   : August
# ───────────────────────────────────────────────

# %% [markdown]
# <div style="font-size:18px; font-weight:bold; color:#FF0000;">
# !! Create a Lakehouse or attach the notebook to your existing lakehouse and run the below cells
# </div>

# %%
# %pip install semantic-link-labs==0.11.3
# Out:
# Requirement already satisfied: semantic-link-labs==0.11.3 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (0.11.3)
# Requirement already satisfied: semantic-link-sempy>=0.11.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-labs==0.11.3) (0.11.2)
# Requirement already satisfied: anytree in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-labs==0.11.3) (2.13.0)
# Requirement already satisfied: polib in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-labs==0.11.3) (1.2.0)
# Requirement already satisfied: jsonpath_ng in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-labs==0.11.3) (1.7.0)
# Requirement already satisfied: clr-loader>=0.2.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (0.2.7.post0)
# Requirement already satisfied: graphviz>=0.20.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (0.20.3)
# Requirement already satisfied: pyarrow>=12.0.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (17.0.0)
# Requirement already satisfied: pythonnet>=3.0.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (3.0.3)
# Requirement already satisfied: scikit-learn>=1.2.2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (1.5.0)
# Requirement already satisfied: setuptools>=68.2.2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (80.9.0)
# Requirement already satisfied: tqdm>=4.65.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (4.66.4)
# Requirement already satisfied: rich>=13.3.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (13.9.4)
# Requirement already satisfied: regex>=2023.8.8 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (2023.12.25)
# Requirement already satisfied: pandas>=1.5.3 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (2.1.4)
# Requirement already satisfied: pyspark>=3.4.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (3.5.1.5.4.20240407)
# Requirement already satisfied: requests>=2.31.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (2.32.3)
# Requirement already satisfied: aiohttp>=3.8.6 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (3.11.11)
# Requirement already satisfied: IPython>=8.14.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (8.20.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (9.0.0)
# Requirement already satisfied: ply in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from jsonpath_ng->semantic-link-labs==0.11.3) (3.11)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (1.20.0)
# Requirement already satisfied: cffi>=1.17 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from clr-loader>=0.2.5->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (1.17.1)
# Requirement already satisfied: decorator in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (2.19.1)
# Requirement already satisfied: stack-data in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (4.9.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (2025.2)
# Requirement already satisfied: py4j==0.10.9.7 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from pyspark>=3.4.1->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (0.10.9.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (2024.7.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from rich>=13.3.5->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (3.0.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (3.6.0)
# Requirement already satisfied: pycparser in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from cffi>=1.17->clr-loader>=0.2.5->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from jedi>=0.16->IPython>=8.14.0->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.3.5->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from pexpect>4.3->IPython>=8.14.0->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (0.7.0)
# Requirement already satisfied: wcwidth in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython>=8.14.0->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (0.2.13)
# Requirement already satisfied: six>=1.5 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.3->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (3.0.0)
# Requirement already satisfied: pure_eval in /home/trusted-service-user/jupyter-env/python3.11/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.11.1->semantic-link-labs==0.11.3) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
## Install if not available in your environment.

# %pip install semantic-link==0.11.2

# %%
import os
import requests 
import pandas as pd
import re
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Helper funtion to save the .py file from github

# %%
#Function to save the dependent utils files from my github repo to the lakehouse's resources section

def save_from_github(github_url: str, file_name: str, force: bool = False):
    """
    Downloads a file from GitHub and saves it under Lakehouse's resources as a file
    
    Args:
        url (str): The URL to download from (use raw.githubusercontent.com).
        file_name (str): The name of the file to save locally.
        force (bool): If True, always download and overwrite the file.
    """
    url = github_url.replace("github.com", "raw.githubusercontent.com").replace("/blob/", "/")
    dest_path = f"./builtin/{file_name}"
    file_exists = os.path.exists(dest_path)
    if file_exists and not force:
        print(f"❗'{file_name}' already exists. Skipping download.")
    os.makedirs(os.path.dirname(dest_path), exist_ok=True)
    response = requests.get(url)
    if response.status_code == 200:
        with open(dest_path, 'wb') as f:
            f.write(response.content)
        if file_exists & force:
            print(f"📝 Overwritten the existing '{file_name}' with the latest file.")
        elif not file_exists :
            print(f"📥 Downloaded and saved '{file_name}'.")
    else:
        print(f"🔴 Failed to download. Status: {response.status_code}, URL: {url}")

# %%
# Saves the "custom_utils.py" file from my repository to the Notebooks resources section

save_from_github( github_url="https://github.com/jai-rathinavel/my-packages/blob/main/sempy/custom_utils.py",file_name='custom_utils.py',force=True)
# Out:
# 📥 Downloaded and saved 'custom_utils.py'.

# %% [markdown]
# ### Importing the custom functions from the .py file

# %%
#Importing all the functions and libraries from custom_utils.py file

from builtin.custom_utils import get_model_details, launch_enhanced_refresh_ui

# %% [markdown]
# ### Prerequisites

# %% [markdown]
# ### Understanding the custom functions

# %%
#The below function is built on top of semantic-link (sempy) framework
#It extracts the tables and partitions across the models on workspace level.
#This function works only with Python Runtime.

help(get_model_details)
# Out:
# Help on function get_model_details in module builtin.custom_utils:
#
# get_model_details(load_from_lakehouse: bool, table_name: str, workspace_list: list = None, only_premium_ws: bool = True) -> pandas.core.frame.DataFrame
#     Function to extract all semantic models and its tables and partitions of the executing user.
#
#     load_from_lakehouse: set to False will extract the latest information across all the semantic models and writes to lakehouse.
#     table_name: name of the lakehouse table.
#     workspace_list: ['Workspace1','Workspace2'], if not provided it will extract all the accesible workspaces data
#     only_premium_ws: by default set to True to fetch only premium workspaces

# %%
#The below function is built on top of semantic-link-labs (sempy_labs) framework
#Launches an Simple UI to handle refreshes within the notebook runtime. 

help(launch_enhanced_refresh_ui)
# Out:
# Help on function launch_enhanced_refresh_ui in module builtin.custom_utils:
#
# launch_enhanced_refresh_ui(input_df, show_author: bool = True)
#     Launches an interactive, enhanced UI for refreshing semantic models.
#     This function creates a user interface for selecting workspaces, models, tables, and partitions from the provided DataFrame.
#     It allows users to configure advanced refresh options such as refresh type, retry count, parallelism, commit mode, and policy application.
#     The UI supports search and filtering for artifacts and dynamically updates available options based on user selections.
#     Upon triggering the refresh, the function leverages sempy under the hood to trace the refresh activities.
#     Parameters
#     ----------
#     input_df : pandas.DataFrame
#         A DataFrame containing at least the columns: "Workspace Name", "Workspace Id", "Dataset Name", "Dataset Id", "Table Name", "Partition Name" and "Workspace Flag".
#         This DataFrame is used to populate the dropdowns and selection widgets in the UI.
#     Returns
#     -------
#     None
#         Displays the interactive UI in a Notebook environment.

# %% [markdown]
# ### Understanding the parameters

# %%
# Sample Code to extract datasets across all the premium workspaces.

result_df = get_model_details(load_from_lakehouse=False,table_name='Model Details',only_premium_ws=True)

#Took around 12mins & 21secs to extract 93 datasets (along with tables and partitions)
# Out:
# ✅ Extracted 94 models info across 20 workspaces
# 🟢 'Model Details' table saved to the Lakehouse

# %%
# Sample Code to extract datasets from specific workspaces.

result_df = get_model_details(load_from_lakehouse=False,table_name='Model Details',workspace_list=['Financial Observations','Rest API'],only_premium_ws=False)
# Out:
# ✅ Extracted 22 models info across 2 workspaces
# 🟢 'Model Details' table saved to the Lakehouse

# %%
# Sample Code to get all pre loaded data from the lakehouse (to eliminate redundant notebook runs)

result_df = get_model_details(load_from_lakehouse=True,table_name='Model Details')
# Out:
# ✅ Found 94 models info from 20 workspaces

# %%
# Sample Code to get all pre loaded data from the lakehouse filtered for specific workspaces

result_df = get_model_details(load_from_lakehouse=True,table_name='Model Details',workspace_list=['Financial Observations','Rest API'])
# Out:
# ✅ Found 22 models info from 2 workspaces

# %%
#Uncomment and run this helper to understand about refresh_semantic_model function from sempy_labs

#help(refresh_semantic_model)

# %% [markdown]
# ### Populating the dataframe

# %%
#❗the UI function will not work without a valid dataframe❗

result_df = get_model_details(load_from_lakehouse=True,table_name='Dataset Details',only_premium_ws=True)
display(result_df.tail())
# Out:
# ✅ Found 22 models info from 2 workspaces

# %%
# 📌 Notes (please read before running the application):

# If you don’t select any tables, all tables will be refreshed by default.
# If you select a table but don’t select any partitions, all partitions of that table will be refreshed.
# If you select specific partitions of a table, only those partitions will be refreshed.
# If no partitions are selected for a chosen table, then all partitions of that table will be refreshed.
# App may display "no such commm ...." junk values when the App is launched for first time, please re-run the cell to fix it.
# Dropdown values load depends on the size of the DataFrame. Larger DataFrames may cause a delay.

# %% [markdown]
# ## ⚡Launching the Notebook Application

# %%
#Passing the result_df dataframe from above 

launch_enhanced_refresh_ui(input_df=result_df)
# Out:
# VBox(children=(HTML(value='<div style="font-size:20px;font-weight:bold;padding:10px;color:white;background:lin…

# %%
#Output (SSAS Trace output from sempy_labs package)

launch_enhanced_refresh_ui(input_df=result_df)
# Out:
#     <!DOCTYPE html>
#     <html>
#         <head>
#             <script src="https://cdn.jsdelivr.net/npm/vega@5"></script>
#             <script src="https://cdn.jsdelivr.net/npm/vega-lite@5"></script>
#             <script src="https://cdn.jsdelivr.net/npm/vega-embed@6"></script>
#             <style>
#                 table, th, td {
#                 border: 10px solid #e7e9eb;
#                 border-collapse: collapse;
#                 }
#             </style>
#         </head>
#         <body>
#             <table>
#                 <tr>
#                     <td style="text-align: center;">
#                         <h1>Refresh Completed</h1>
#                     </td>
#                 </tr>
#                 <tr>
#                     <td>
#                         <div id="vis"></div>
#                     </td>
#                 </tr>
#             </table>
#             <script type="text/javascript">
#                 var spec = {
#         "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
#         "description": "A simple bar chart with ranged data (aka Gantt Chart).",
#         "data": { "values": [{"Event Class":"ProgressReportEnd","Event Subclass":"ExecuteSql","Current Time":1756148207316,"Text Data":"let __AS_Query__ = #\"Dim Location\"\n,\n__AS_Table__ = Table.FromValue(__AS_Query__),\n__AS_Compact__ = Table.RemoveColumns(__AS_Table__, Table.ColumnsOfType(__AS_Table__, { type table, type record, type list })),\n__AS_Effective__ = Table.TransformColumnNames(__AS_Compact__, Text.Clean),\n__M = #shared[[List.ConformToPageReader],[Graph.Nodes],[Value.Lineage]]?,\n__AS_TransformClassification__ = (value) => Value.ReplaceType(Table.Distinct(List.Accumulate(__M[Graph.Nodes](__M[Value.Lineage](value)), #table({\"ColumnName\", \"LabelId\"}, {}), (current, node) => Table.Combine({current, Table.SelectColumns(Table.ExpandRecordColumn(Table.SelectRows(Value.Traits(node), each ([Provider] = \"SQL\" or [Provider] = \"MicrosoftInformationProtection\") and [Identifier] = \"Classification\"), \"Value\", {\"LabelId\"}), {\"ColumnName\", \"LabelId\"}, MissingField.UseNull)}))), type table [ColumnName=nullable text, LabelId = text]),\n__AS_WithClassification__ = __M[List.ConformToPageReader]({__AS_Effective__, __AS_TransformClassification__}),\n__AS_Result__ = if __M[List.ConformToPageReader] = null then __AS_Effective__ else __AS_WithClassification__\nin __AS_Result__","Start Time":1756148206363,"End Time":1756148207316,"Duration":953,"Cpu Time":0,"Success":"Success","Integer Data":0,"Object ID":"263","PartitionID":"263","Object Name":"Dim Location","TableName":"Dim Location","PartitionName":"Dim Location","Start":0.0,"End":953.0},{"Event Class":"ProgressReportEnd","Event Subclass":"Process","Current Time":1756148207333,"Text Data":"Finished processing the '<oii>Dim Location<\/oii>' partition of the '<oii>Dim Location<\/oii>' table. (TableTMID='39', PartitionTMID='263')","Start Time":1756148207316,"End Time":1756148207333,"Duration":16,"Cpu Time":16,"Success":"Success","Integer Data":0,"Object ID":"263","PartitionID":"263","Object Name":"Dim Location","TableName":"Dim Location","PartitionName":"Dim Location","Start":953.0,"End":970.0},{"Event Class":"ProgressReportEnd","Event Subclass":"Process","Current Time":1756148207363,"Text Data":"Finished processing the '<oii>LocalDateTable_19ee4546-84e5-439b-87da-210b141df6a4<\/oii>' partition of the '<oii>LocalDateTable_19ee4546-84e5-439b-87da-210b141df6a4<\/oii>' table. (TableTMID='42', PartitionTMID='264')","Start Time":1756148207363,"End Time":1756148207363,"Duration":0,"Cpu Time":0,"Success":"Success","Integer Data":0,"Object ID":"264","PartitionID":"264","Object Name":"LocalDateTable_19ee4546-84e5-439b-87da-210b141df6a4","TableName":"LocalDateTable_19ee4546-84e5-439b-87da-210b141df6a4","PartitionName":"LocalDateTable_19ee4546-84e5-439b-87da-210b141df6a4","Start":1000.0,"End":1000.0},{"Event Class":"ProgressReportEnd","Event Subclass":"ExecuteSql","Current Time":1756148208020,"Text Data":"let __AS_Query__ = #\"Dim Ledgers\"\n,\n__AS_Table__ = Table.FromValue(__AS_Query__),\n__AS_Compact__ = Table.RemoveColumns(__AS_Table__, Table.ColumnsOfType(__AS_Table__, { type table, type record, type list })),\n__AS_Effective__ = Table.TransformColumnNames(__AS_Compact__, Text.Clean),\n__M = #shared[[List.ConformToPageReader],[Graph.Nodes],[Value.Lineage]]?,\n__AS_TransformClassification__ = (value) => Value.ReplaceType(Table.Distinct(List.Accumulate(__M[Graph.Nodes](__M[Value.Lineage](value)), #table({\"ColumnName\", \"LabelId\"}, {}), (current, node) => Table.Combine({current, Table.SelectColumns(Table.ExpandRecordColumn(Table.SelectRows(Value.Traits(node), each ([Provider] = \"SQL\" or [Provider] = \"MicrosoftInformationProtection\") and [Identifier] = \"Classification\"), \"Value\", {\"LabelId\"}), {\"ColumnName\", \"LabelId\"}, MissingField.UseNull)}))), type table [ColumnName=nullable text, LabelId = text]),\n__AS_WithClassification__ = __M[List.ConformToPageReader]({__AS_Effective__, __AS_TransformClassification__}),\n__AS_Result__ = if __M[List.ConformToPageReader] ...
#         "width": 700,
#         "hei
# 🟢 Refresh 'full' of the 'Logistics Spend Analysis - DS' semantic model within the 'Financial Observations' workspace is complete.
#          Event Class Event Subclass            Current Time  \
# 0  ProgressReportEnd     ExecuteSql 2025-08-25 18:56:47.316
# 1  ProgressReportEnd        Process 2025-08-25 18:56:47.333
# 2  ProgressReportEnd        Process 2025-08-25 18:56:47.363
# 3  ProgressReportEnd     ExecuteSql 2025-08-25 18:56:48.020
# 4  ProgressReportEnd     ExecuteSql 2025-08-25 18:56:48.050
# 5  ProgressReportEnd        Process 2025-08-25 18:56:48.050
# 6  ProgressReportEnd        Process 2025-08-25 18:56:49.943
#
#                                            Text Data              Start Time  \
# 0  let __AS_Query__ = #"Dim Location"
# ,
# __AS_Tabl... 2025-08-25 18:56:46.363
# 1  Finished processing the '<oii>Dim Location</oi... 2025-08-25 18:56:47.316
# 2  Finished processing the '<oii>LocalDateTable_1... 2025-08-25 18:56:47.363
# 3  let __AS_Query__ = #"Dim Ledgers"
# ,
# __AS_Table... 2025-08-25 18:56:46.363
# 4  let __AS_Query__ = Parcels
# ,
# __AS_Table__ = Ta... 2025-08-25 18:56:46.363
# 5  Finished processing the '<oii>Parcels</oii>' p... 2025-08-25 18:56:48.050
# 6  Finished processing the '<oii>Dim Ledgers</oii... 2025-08-25 18:56:48.020
#
#                  End Time  Duration  Cpu Time  Success  Integer Data  \
# 0 2025-08-25 18:56:47.316       953         0  Success             0
# 1 2025-08-25 18:56:47.333        16        16  Success             0
# 2 2025-08-25 18:56:47.363         0         0  Success             0
# 3 2025-08-25 18:56:48.020      1656         0  Success             0
# 4 2025-08-25 18:56:48.050      1688         0  Success             0
# 5 2025-08-25 18:56:48.050         0         0  Success             0
# 6 2025-08-25 18:56:49.943      1922      1828  Success             0
#
#   Object ID                                         Table Name  \
# 0       263                                       Dim Location
# 1       263                                       Dim Location
# 2       264  LocalDateTable_19ee4546-84e5-439b-87da-210b141...
# 3       271                                        Dim Ledgers
# 4       273                                            Parcels
# 5       273                                            Parcels
# 6       271                                        Dim Ledgers
#
#                                       Partition Name        Start          End
# 0                                       Dim Location     0.000000   953.000000
# 1                                       Dim Location   953.000000   970.000000
# 2  LocalDateTable_19ee4546-84e5-439b-87da-210b141...  1000.000000  1000.000000
# 3                                        Dim Ledgers     0.000000  1657.000000
# 4                                            Parcels     0.000000  1686.999756
# 5                                            Parcels  1686.999756  1686.999756
# 6                                        Dim Ledgers  1657.000000  3580.000000
